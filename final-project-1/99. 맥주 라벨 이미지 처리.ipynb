# %% [markdown]
# ## Tesseract

# %%
import numpy as np
import pandas as pd
import time
import pytesseract
from PIL import Image
import re
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.5.0

# %%
img = Image.open('image.png')
text = pytesseract.image_to_string(img,lang='eng')
print(text)
# Out:
# Python Tesseract Test

# %% [markdown]
# **맥주 라벨 이미지에서 텍스트 추출**

# %% [markdown]
# ![test3.png](attachment:test3.png)

# %%
img = Image.open('image/test3.png')
text = pytesseract.image_to_string(img,lang='kor')
print(text)
# Out:
# ~
#
# 70001
#
# 스위트하게~ 위트있거~
#
# 우리나라 밀맥주
#
#
#
# 4.5% 시. /60. 50001
#
# …ㅡ……
